# %% [markdown]
# # Photo Gradient
# Creates a nice gradient as seen on instagram. View examples below.

# %%
REF_PHOTO_DIR = "ref_photos/"
from IPython.display import Image

Image(filename=REF_PHOTO_DIR + 'dad_inst.jpeg', width = 200)
